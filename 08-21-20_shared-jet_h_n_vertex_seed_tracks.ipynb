# %%
import sys
# !{sys.executable} -m pip install scipy

# %%
import numpy as np
from scipy import linalg 
import glob, os
import matplotlib.pyplot as plt
# %matplotlib notebook
import mpld3
mpld3.enable_notebook()

# %%
lifetimes = [300,1000,10000]
mass_800GeV = [11.74, 13.36, 15.27]
mass_1_6TeV = [3.16, 4.92, 10.36]
mass_3TeV = [-6.58,0.99,9.44]

plt.figure(1)
plt.rcParams["figure.figsize"] = [7,4]
plt.plot(lifetimes,mass_800GeV,label='800 GeV')
plt.plot(lifetimes,mass_1_6TeV,label='1.6 TeV')
plt.plot(lifetimes,mass_3TeV,label='3 TeV')
plt.legend()
plt.title('Sensitivity of lifetimes by masspoints to the difference between dijet and multijet \n from the distribution of vertex seed tracks')
plt.xlabel('lifetimes (um)')
plt.ylabel('Difference in percents')
# Out:
# <img src="data:image/png;base64,..." width="700">
# Text(0, 0.5, 'Difference in percents')

# %%
mpoints = [800,1600,3000]
tau_300um = [11.74, 3.16, 0.07]
tau_1mm = [13.36, 4.92, 0.98]
tau_10mm = [15.27,10.36,9.44]

plt.figure(2)
plt.rcParams["figure.figsize"] = [7,4]
plt.plot(mpoints,tau_300um,label='300 um')
plt.plot(mpoints,tau_1mm,label='1 mm')
plt.plot(mpoints,tau_10mm,label='10 mm')
plt.legend()
plt.title('Sensitivity of masspoints by lifetimes to the difference between dijet and multijet \n from the distribution of vertex seed tracks')
plt.xlabel('masspoints (GeV)')
plt.ylabel('Difference in percents')
# Out:
# <img src="data:image/png;base64,..." width="700">
# Text(0, 0.5, 'Difference in percents')

# %%
lifetimes = [300,1000,10000]
mass_800GeV = [37.49, 42.8, 42.36]
mass_1_6TeV = [46.49, 53.87, 53.4]
mass_3TeV = [54.73,64.9,64.51]

plt.figure(3)
plt.rcParams["figure.figsize"] = [7,4]
plt.plot(lifetimes,mass_800GeV,label='800 GeV')
plt.plot(lifetimes,mass_1_6TeV,label='1.6 TeV')
plt.plot(lifetimes,mass_3TeV,label='3 TeV')
plt.legend()
plt.title('Average seed tracks as a function of lifetimes by a fixed masspoint \n 2017 Dijet')
plt.xlabel('lifetimes (um)')
plt.ylabel('# vertex seed tracks')
# Out:
# <img src="data:image/png;base64,..." width="700">
# Text(0, 0.5, '# vertex seed tracks')

# %%
lifetimes = [300,1000,10000]
mass_800GeV = [41.89, 48.52, 48.83]
mass_1_6TeV = [47.98, 56.52, 58.93]
mass_3TeV = [54.77,65.54,70.6]

plt.figure(4)
plt.rcParams["figure.figsize"] = [7,4]
plt.plot(lifetimes,mass_800GeV,label='800 GeV')
plt.plot(lifetimes,mass_1_6TeV,label='1.6 TeV')
plt.plot(lifetimes,mass_3TeV,label='3 TeV')
plt.legend()
plt.title('Average seed tracks as a function of lifetimes by a fixed masspoint \n 2017 Multijet')
plt.xlabel('lifetimes (um)')
plt.ylabel('# vertex seed tracks')
# Out:
# <img src="data:image/png;base64,..." width="700">
# Text(0, 0.5, '# vertex seed tracks')

# %%
mpoints = [800,1600,3000]
tau_300um = [37.49, 46.49, 54.73]
tau_1mm = [42.8, 53.87, 64.9]
tau_10mm = [42.36, 53.4, 64.51]

plt.figure(5)
plt.rcParams["figure.figsize"] = [7,4]
plt.plot(mpoints,tau_300um,label='300 um')
plt.plot(mpoints,tau_1mm,label='1 mm')
plt.plot(mpoints,tau_10mm,label='10 mm')
plt.legend()
plt.title('Average seed tracks as a function of masspoints by a fixed lifetime \n 2017 Dijet')
plt.xlabel('masspoints (GeV)')
plt.ylabel('# vertex seed tracks')
# Out:
# <img src="data:image/png;base64,..." width="700">
# Text(0, 0.5, '# vertex seed tracks')

# %%
mpoints = [800,1600,3000]
tau_300um = [41.89, 47.98, 54.77]
tau_1mm = [48.52, 56.52, 65.54]
tau_10mm = [48.83, 58.93, 70.6]

plt.figure(6)
plt.rcParams["figure.figsize"] = [7,4]
plt.plot(mpoints,tau_300um,label='300 um')
plt.plot(mpoints,tau_1mm,label='1 mm')
plt.plot(mpoints,tau_10mm,label='10 mm')
plt.legend()
plt.title('Average seed tracks as a function of masspoints by a fixed lifetime \n 2017 Multijet')
plt.xlabel('masspoints (GeV)')
plt.ylabel('# vertex seed tracks')
# Out:
# <img src="data:image/png;base64,..." width="700">
# Text(0, 0.5, '# vertex seed tracks')
